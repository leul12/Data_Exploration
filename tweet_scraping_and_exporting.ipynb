# %% [markdown]
# <a href="https://colab.research.google.com/github/leul12/Data_Exploration/blob/main/tweet_stalking_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import itertools
from datetime import datetime
import datetime
import time
from pandas.io.json import json_normalize
import json
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## Let's Check the version 🐍

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.16

# %% [markdown]
# ## Okay now we can do our **job**
#
# 1.   Let's install the 🔨
# 2.   Extract the 🗄️
# 3.   And So on

# %% [markdown]
# # ⬆️ install the tool 🔨

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-qdkf_0yp
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-qdkf_0yp
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit cbdaee6864aa8d3e9e4326d4fe224a517aabbc2c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape==0.4.3.20220107.dev73+gcbdaee6) (2.25.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape==0.4.3.20220107.dev73+gcbdaee6) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape==0.4.3.20220107.dev73+gcbdaee6) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape==0.4.3.20220107.dev73+gcbdaee6) (3.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape==0.4.3.20220107.dev73+gcbdaee6) (2022.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape==0.4.3.20220107.dev73+gcbdaee6) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape==0.4.3.20220107.dev73+gcbdaee6) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape==0.4.3.20220107.dev73+gcbdaee6) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape==0.4.3.20220107.dev73+gcbdaee6) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape==0.4.3.20220107.dev73+gcbdaee6) (1.7.1)

# %% [markdown]
# ## 🤔   **how to extract the tweets ?** no worries ⬇️

# %%
import snscrape.modules.twitter as sntwitter

# %% [markdown]
# # okay now some magic to get the actual 🐦 using the **itertools** 😉

# %%
df = pd.DataFrame(itertools.islice(
    sntwitter.TwitterSearchScraper('#vaccine').get_items(), 30000))
# let's Test what kind of data we can get from it (if it works)
df.head(2)
# Out:
#                                                  url  \
# 0  https://twitter.com/Healthcare_GD/status/16113...
# 1  https://twitter.com/Newsfilter2/status/1611336...
#
#                        date  \
# 0 2023-01-06 12:21:03+00:00
# 1 2023-01-06 12:18:01+00:00
#
#                                           rawContent  \
# 0  Monoclonal antibodies have been dominating Alz...
# 1  The #WEF just can't wait to rewrite your #DNA ...
#
#                                      renderedContent                   id  \
# 0  Monoclonal antibodies have been dominating Alz...  1611337044759908352
# 1  The #WEF just can't wait to rewrite your #DNA ...  1611336280620539904
#
#                                                 user  replyCount  \
# 0  {'username': 'Healthcare_GD', 'id': 113373418,...           0
# 1  {'username': 'Newsfilter2', 'id': 105474057648...           0
#
#    retweetCount  likeCount  quoteCount  ...  retweetedTweet quotedTweet  \
# 0             0          0           0  ...            None        None
# 1             0          0           0  ...            None        None
#
#   inReplyToTweetId inReplyToUser mentionedUsers coordinates place  \
# 0              NaN          None           None        None  None
# 1              NaN          None           None        None  None
#
#                                             hashtags cashtags  card
# 0                        [Alzheimers, vaccine, mAbs]     None  None
# 1  [WEF, DNA, mRNA, StoptheShotsNow, vaccine, Gen...     None  None
#
# [2 rows x 27 columns]

# %% [markdown]
# # okay Now that we got this out of the way what now 🤔
#
#
# *   we check data heads
# *   clean some columns [user , hastags , date , mentionedUsers & inReplyToUser ]
# *   and take it form there
# *   🚶‍♂️

# %%
dfuser= pd.json_normalize(df['user'])
dfuser.head(2)
# Out:
#         username                   id            displayname  \
# 0  Healthcare_GD            113373418  GlobalData Healthcare
# 1    Newsfilter2  1054740576485236736             Vidmax.com
#
#                                       rawDescription  \
# 0  We have decades of experience working as an in...
# 1  #Conservative #Freedom #StopTheShots #FauciLie...
#
#                                  renderedDescription descriptionLinks  \
# 0  We have decades of experience working as an in...             None
# 1  #Conservative #Freedom #StopTheShots #FauciLie...             None
#
#    verified                   created  followersCount  friendsCount  ...  \
# 0     False 2010-02-11 15:09:21+00:00            2644          1339  ...
# 1     False 2018-10-23 14:25:24+00:00            1443            62  ...
#
#    label                       link.text  \
# 0    NaN  globaldata.com/industries-we-…
# 1    NaN                      vidmax.com
#
#                                           link.url              link.tcourl  \
# 0  https://www.globaldata.com/industries-we-cover/  https://t.co/2kUafMawAY
# 1                              https://vidmax.com/  https://t.co/cfcuKPB0AN
#
#   link.indices  link label.description label.url  label.badgeUrl  \
# 0      (0, 23)   NaN               NaN       NaN             NaN
# 1      (0, 23)   NaN               NaN       NaN             NaN
#
#   label.longDescription
# 0                   NaN
# 1                   NaN
#
# [2 rows x 28 columns]

# %% [markdown]
# # NOw Let's Take what we need and add the to the main Data Frame ⚙️

# %%
dfuser.drop(['id','displayname','rawDescription','renderedDescription','descriptionLinks','location','statusesCount','favouritesCount','listedCount',
                  'mediaCount','link','profileImageUrl','profileBannerUrl','label','link.text','link.url','link.tcourl','link.indices'], axis = 1, inplace = True)
dfuser.head(2)
# Out:
#         username  verified                   created  followersCount  \
# 0  Healthcare_GD     False 2010-02-11 15:09:21+00:00            2644
# 1    Newsfilter2     False 2018-10-23 14:25:24+00:00            1443
#
#    friendsCount  protected label.description label.url label.badgeUrl  \
# 0          1339      False               NaN       NaN            NaN
# 1            62      False               NaN       NaN            NaN
#
#   label.longDescription
# 0                   NaN
# 1                   NaN

# %% [markdown]
# # now that we 🫧 the 🧫  time to add it to the clean data sets

# %%
df2=df.drop(['user','renderedContent','sourceUrl','hashtags','cashtags','card','inReplyToTweetId','inReplyToUser','mentionedUsers','coordinates','links','media','retweetedTweet','quotedTweet','place'],axis=1)
df2.head(2)
# Out:
#                                                  url  \
# 0  https://twitter.com/Healthcare_GD/status/16113...
# 1  https://twitter.com/Newsfilter2/status/1611336...
#
#                        date  \
# 0 2023-01-06 12:21:03+00:00
# 1 2023-01-06 12:18:01+00:00
#
#                                           rawContent                   id  \
# 0  Monoclonal antibodies have been dominating Alz...  1611337044759908352
# 1  The #WEF just can't wait to rewrite your #DNA ...  1611336280620539904
#
#    replyCount  retweetCount  likeCount  quoteCount       conversationId lang  \
# 0           0             0          0           0  1611337044759908352   en
# 1           0             0          0           0  1611336280620539904   en
#
#                                               source      sourceLabel
# 0  <a href="https://www.oktopost.com" rel="nofoll...         Oktopost
# 1  <a href="https://mobile.twitter.com" rel="nofo...  Twitter Web App

# %% [markdown]
# # 🔗 the dataframes into 1

# %%
result = pd.concat([df2, dfuser], axis=1)
result.reset_index(drop=True)
result.head(2)
# Out:
#                                                  url  \
# 0  https://twitter.com/Healthcare_GD/status/16113...
# 1  https://twitter.com/Newsfilter2/status/1611336...
#
#                        date  \
# 0 2023-01-06 12:21:03+00:00
# 1 2023-01-06 12:18:01+00:00
#
#                                           rawContent                   id  \
# 0  Monoclonal antibodies have been dominating Alz...  1611337044759908352
# 1  The #WEF just can't wait to rewrite your #DNA ...  1611336280620539904
#
#    replyCount  retweetCount  likeCount  quoteCount       conversationId lang  \
# 0           0             0          0           0  1611337044759908352   en
# 1           0             0          0           0  1611336280620539904   en
#
#    ...       username verified                   created  followersCount  \
# 0  ...  Healthcare_GD    False 2010-02-11 15:09:21+00:00            2644
# 1  ...    Newsfilter2    False 2018-10-23 14:25:24+00:00            1443
#
#   friendsCount  protected  label.description  label.url label.badgeUrl  \
# 0         1339      False                NaN        NaN            NaN
# 1           62      False                NaN        NaN            NaN
#
#   label.longDescription
# 0                   NaN
# 1                   NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# # let's make the date column the first column ⛹

# %%
def swap_columns(result, col1, col2):
    col_list = list(result.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    result = result[col_list]
    return result
res = swap_columns(result,'url','date')

# %% [markdown]
# # ⏱️ manuplation

# %%
res.sort_values('date')
res.head(2)
# Out:
#                        date  \
# 0 2023-01-06 12:21:03+00:00
# 1 2023-01-06 12:18:01+00:00
#
#                                                  url  \
# 0  https://twitter.com/Healthcare_GD/status/16113...
# 1  https://twitter.com/Newsfilter2/status/1611336...
#
#                                           rawContent                   id  \
# 0  Monoclonal antibodies have been dominating Alz...  1611337044759908352
# 1  The #WEF just can't wait to rewrite your #DNA ...  1611336280620539904
#
#    replyCount  retweetCount  likeCount  quoteCount       conversationId lang  \
# 0           0             0          0           0  1611337044759908352   en
# 1           0             0          0           0  1611336280620539904   en
#
#    ...       username verified                   created  followersCount  \
# 0  ...  Healthcare_GD    False 2010-02-11 15:09:21+00:00            2644
# 1  ...    Newsfilter2    False 2018-10-23 14:25:24+00:00            1443
#
#   friendsCount  protected  label.description  label.url label.badgeUrl  \
# 0         1339      False                NaN        NaN            NaN
# 1           62      False                NaN        NaN            NaN
#
#   label.longDescription
# 0                   NaN
# 1                   NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# ## date 🔪 into month week hour and so on and drop the old column "date" **💂**

# %%
res['date'] = pd.to_datetime(res['date'])
datetime_col = ['date']
def extract_date_info(df, col,):
    for feat in col:
        res[feat +'_day'] = res[feat].dt.day
        res[feat +'_month'] = res[feat].dt.month
        res[feat+'_WeekDay'] = res[feat].dt.weekday
        res[feat+'_Quarter'] = res[feat].dt.quarter
        res[feat+'_year'] = res[feat].dt.year
        res['Tweet time'] = res[feat].dt.time
        res['monthname'] = res[feat].dt.month_name()
        res['dayname'] = res[feat].dt.day_name()
    res.drop(columns=col,axis=1,inplace=True)

extract_date_info(res, datetime_col)

# %% [markdown]
# # Now all that left is to 📥 the clean data to csv for keeping the record.

# %%
res.to_csv('vaccine.csv',index=False)

# %% [markdown]
# ## **okay now that we got all that we need what next**
# 1. we can do statical annalysis on the data
# 2. we can even do sentimental analysis
# 3. we can basically do what ever we want with this data
# #                                                         END OF PART ONE 🎦
